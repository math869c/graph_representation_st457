# %%
##############################################
##############################################
### TO GET ACCESS TO FILE IN GOOGLE COLAB ###
##############################################
##############################################

# To get access to the data files from github in Google Colab
#!git clone https://github.com/math869c/graph_representation_st457.git

# set the folder to get access to the data
#import os
#os.chdir('/content') # to avoid error if rerun
#os.chdir('./graph_representation_st457')

#import sys
#sys.path.append("/Users/stephwenninger/Desktop/LSE/ST457/graph_representation_st457")

# %%
# installation of Pytorch Geometric. This may take up to 30 minutes!!!

#!pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
#!pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
#!pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# install DGL
#!pip install dgl
#!pip install numpy==1.26.4

# %%
# import pandas as pd
# import seaborn as sns
# import numpy as np
# import matplotlib.pyplot as plt
# import torch.nn as nn
# import torch
# import torch.optim as optim
# import json

# # load from other folders
# from helper_functions_steph import *
# from model_classes_steph import *

# %%
import os, sys
os.chdir(r'C:\Users\aryaa\graph_representation_st457\Tune_models_ipynb')
sys.path.append(r'C:\Users\aryaa\graph_representation_st457')
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import json
from itertools import product

from model_classes import GAT, GAT_RotatE
from helper_functions import create_data, train_one_epoch_GAT, evaluate_GAT, predict_GAT, compute_metrics, build_edges, train_one_epoch_GAT_RotatE, evaluate_GAT_RotatE, predict_GAT_RotatE

# %%
import os
print(os.getcwd())
print(os.listdir('../'))
# Out:
# C:\Users\aryaa\graph_representation_st457\Tune_models_ipynb
# ['.git', '.ipynb_checkpoints', 'Best_model', 'Best_models', 'data_folder', 'data_maker.py', 'helper_functions.py', 'model_classes.py', 'model_ipynb', 'Old_notebooks', 'README.md', 'Tune_models_ipynb', '__pycache__']

# %% [markdown]
# # Load data for GAT+RotatE

# %%
# Stock prices
open_prices_interp = pd.read_csv('../data_folder/open_prices_interp.csv', index_col=0)
x = open_prices_interp.to_numpy()
tickers_with_data = open_prices_interp.columns

# Load graph data
with open("../data_folder/firm_industry.json", "r") as f:
    firm_industry_dict = json.load(f)
A = np.load("../data_folder/adjacency_matrix.npy")
adj_matrix = torch.tensor(A, dtype=torch.float32)

# make training data
batch_size = 32
X_train, y_train, X_val, y_val, X_test, y_test, sc, train_loader, val_loader, test_loader = create_data(
    x,
    batch_size=batch_size,
    flatten_data=False,
    flatten_time_features=True
)
# Out:
# torch.Size([984, 460, 40])
# torch.Size([984, 460])

# %% [markdown]
# # Train GAT+RotatE model

# %%
# build_edges is imported from helper_functions.py.
# It converts an adjacency tensor [N, N, R] into edge_index and edge_type for the RotatE loss.

# %%
# Tune GAT+RotatE and compare against the same model with lambda_rotate = 0.
# lambda_rotate = 0 is the plain forecasting GAT baseline: no RotatE graph loss is used.
from itertools import product
import copy

seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# I did a relatively small grid search, otherwise this takes ages.
search_space = {
    'c_hidden': [16, 32],
    'emb_dim': [8, 16],
    'num_heads': [2, 4],
    'lr': [1e-3],
    'lambda_rotate': [0.0, 0.1],
    'corr_threshold': [0.5],
}

num_epochs = 8
patience = 2
input_dim = X_train.shape[-1]


def make_adj_matrix(corr_threshold):
    corr = adj_matrix[:, :, 2]
    corr_bin = (corr.abs() > corr_threshold).float()
    corr_bin.fill_diagonal_(1.0)
    return torch.stack([adj_matrix[:, :, 0], adj_matrix[:, :, 1], corr_bin], dim=-1)


def trial_label(lambda_rotate):
    return 'GAT_lambda0' if lambda_rotate == 0 else 'GAT_RotatE'


def build_model(params, num_relations):
    return GAT_RotatE(
        c_in=input_dim,
        c_hidden=params['c_hidden'],
        emb_dim=params['emb_dim'],
        num_relations=num_relations,
        num_heads=params['num_heads'],
    )


results = []
best_by_group = {
    'GAT_lambda0': {'best_val_mse': float('inf')},
    'GAT_RotatE': {'best_val_mse': float('inf')},
}

keys = list(search_space.keys())
param_grid = [dict(zip(keys, values)) for values in product(*(search_space[k] for k in keys))]
print(f'Running {len(param_grid)} hyperparameter trials')

for trial_idx, params in enumerate(param_grid, start=1):
    # GAT hidden size must divide cleanly across attention heads.
    if params['c_hidden'] % params['num_heads'] != 0:
        continue

    torch.manual_seed(seed)
    np.random.seed(seed)

    A_loop = make_adj_matrix(params['corr_threshold'])
    edge_index, edge_type = build_edges(A_loop)
    num_relations = A_loop.shape[-1]

    model = build_model(params, num_relations)
    optimizer = optim.Adam(model.parameters(), lr=params['lr'])

    best_val_mse = float('inf')
    best_state_dict = None
    best_epoch = 0
    patience_counter = 0
    history = []

    print(f"Trial {trial_idx:03d}/{len(param_grid)} | {params}")

    for epoch in range(1, num_epochs + 1):
        train_loss = train_one_epoch_GAT_RotatE(
            model,
            train_loader,
            A_loop,
            edge_index,
            edge_type,
            optimizer,
            lambda_rotate=params['lambda_rotate'],
        )
        val_mse = evaluate_GAT_RotatE(model, val_loader, A_loop)
        history.append({'epoch': epoch, 'train_loss': train_loss, 'val_mse': val_mse})

        print(f"  Epoch {epoch:02d} | train loss {train_loss:.6f} | val MSE {val_mse:.6f}")

        if val_mse < best_val_mse:
            best_val_mse = val_mse
            best_state_dict = copy.deepcopy(model.state_dict())
            best_epoch = epoch
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print('  Early stopping')
                break

    group = trial_label(params['lambda_rotate'])
    result = {
        **params,
        'model_type': group,
        'best_epoch': best_epoch,
        'best_val_mse': best_val_mse,
    }
    results.append(result)

    if best_val_mse < best_by_group[group]['best_val_mse']:
        best_by_group[group] = {
            'best_val_mse': best_val_mse,
            'params': params.copy(),
            'state_dict': best_state_dict,
            'A_loop': A_loop.clone(),
            'history': history,
        }

results_df = pd.DataFrame(results).sort_values('best_val_mse').reset_index(drop=True)
display(results_df)

# Evaluate the best lambda=0 model and the best positive-lambda model on the held-out test set.
final_results = {}
for group, best in best_by_group.items():
    if 'params' not in best:
        continue

    params = best['params']
    A_loop = best['A_loop']
    model = build_model(params, A_loop.shape[-1])
    model.load_state_dict(best['state_dict'])

    pred_test = predict_GAT_RotatE(model, test_loader, A_loop)
    mse_by_firm = np.mean((y_test - pred_test.numpy()) ** 2, axis=0)

    final_results[group] = {
        'params': params,
        'val_mse': best['best_val_mse'],
        'test_mse': mse_by_firm.mean(),
        'mse_by_firm': mse_by_firm,
        'pred': pred_test,
        'model': model,
    }

comparison_df = pd.DataFrame([
    {
        'model_type': group,
        'val_mse': result['val_mse'],
        'test_mse': result['test_mse'],
        **result['params'],
    }
    for group, result in final_results.items()
]).sort_values('val_mse').reset_index(drop=True)

display(comparison_df)
# Out:
# Running 16 hyperparameter trials
# Trial 001/16 | {'c_hidden': 16, 'emb_dim': 8, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 2.009763 | val MSE 0.162816
#   Epoch 02 | train loss 1.341817 | val MSE 0.131743
#   Epoch 03 | train loss 1.218760 | val MSE 0.115148
#   Epoch 04 | train loss 1.152835 | val MSE 0.105435
#   Epoch 05 | train loss 1.114056 | val MSE 0.098199
#   Epoch 06 | train loss 1.089032 | val MSE 0.094566
#   Epoch 07 | train loss 1.068853 | val MSE 0.092030
#   Epoch 08 | train loss 1.054961 | val MSE 0.091701
# Trial 002/16 | {'c_hidden': 16, 'emb_dim': 8, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 17.157219 | val MSE 0.152836
#   Epoch 02 | train loss 7.610027 | val MSE 0.117457
#   Epoch 03 | train loss 5.356171 | val MSE 0.105560
#   Epoch 04 | train loss 4.271325 | val MSE 0.098864
#   Epoch 05 | train loss 3.636247 | val MSE 0.094551
#   Epoch 06 | train loss 3.200207 | val MSE 0.091650
#   Epoch 07 | train loss 2.878927 | val MSE 0.089644
#   Epoch 08 | train loss 2.636758 | val MSE 0.088351
# Trial 003/16 | {'c_hidden': 16, 'emb_dim': 8, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 2.459945 | val MSE 0.189381
#   Epoch 02 | train loss 1.511783 | val MSE 0.149561
#   Epoch 03 | train loss 1.305878 | val MSE 0.129980
#   Epoch 04 | train loss 1.211565 | val MSE 0.119147
#   Epoch 05 | train loss 1.159829 | val MSE 0.111293
#   Epoch 06 | train loss 1.125971 | val MSE 0.105847
#   Epoch 07 | train loss 1.099774 | val MSE 0.101885
#   Epoch 08 | train loss 1.080786 | val MSE 0.099539
# Trial 004/16 | {'c_hidden': 16, 'emb_dim': 8, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 18.147287 | val MSE 0.182698
#   Epoch 02 | train loss 8.650846 | val MSE 0.138679
#   Epoch 03 | train loss 6.310133 | val MSE 0.118372
#   Epoch 04 | train loss 5.074221 | val MSE 0.108281
#   Epoch 05 | train loss 4.318989 | val MSE 0.101524
#   Epoch 06 | train loss 3.783478 | val MSE 0.096924
#   Epoch 07 | train loss 3.375700 | val MSE 0.093954
#   Epoch 08 | train loss 3.058425 | val MSE 0.091853
# Trial 005/16 | {'c_hidden': 16, 'emb_dim': 16, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 1.905250 | val MSE 0.123805
#   Epoch 02 | train loss 1.212131 | val MSE 0.106912
#   Epoch 03 | train loss 1.122603 | val MSE 0.096492
#   Epoch 04 | train loss 1.082117 | val MSE 0.093902
#   Epoch 05 | train loss 1.062049 | val MSE 0.092322
#   Epoch 06 | train loss 1.055176 | val MSE 0.088956
#   Epoch 07 | train loss 1.034829 | val MSE 0.088515
#   Epoch 08 | train loss 1.031008 | val MSE 0.086946
# Trial 006/16 | {'c_hidden': 16, 'emb_dim': 16, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 24.857079 | val MSE 0.116288
#   Epoch 02 | train loss 9.774174 | val MSE 0.100897
#   Epoch 03 | train loss 6.697147 | val MSE 0.094934
#   Epoch 04 | train loss 5.316792 | val MSE 0.091364
#   Epoch 05 | train loss 4.509654 | val MSE 0.089097
#   Epoch 06 | train loss 3.956150 | val MSE 0.087676
#   Epoch 07 | train loss 3.541066 | val MSE 0.086595
#   Epoch 08 | train loss 3.221684 | val MSE 0.085914
# Trial 007/16 | {'c_hidden': 16, 'emb_dim': 16, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 2.090826 | val MSE 0.119486
#   Epoch 02 | train loss 1.214902 | val MSE 0.100125
#   Epoch 03 | train loss 1.128124 | val MSE 0.094901
#   Epoch 04 | train loss 1.087596 | val MSE 0.092546
#   Epoch 05 | train loss 1.067592 | val MSE 0.090729
#   Epoch 06 | train loss 1.057731 | val MSE 0.089294
#   Epoch 07 | train loss 1.036880 | val MSE 0.087570
#   Epoch 08 | train loss 1.032217 | val MSE 0.087777
# Trial 008/16 | {'c_hidden': 16, 'emb_dim': 16, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 29.273462 | val MSE 0.132012
#   Epoch 02 | train loss 11.358276 | val MSE 0.099891
#   Epoch 03 | train loss 7.652597 | val MSE 0.092774
#   Epoch 04 | train loss 6.036044 | val MSE 0.089827
#   Epoch 05 | train loss 5.076771 | val MSE 0.088068
#   Epoch 06 | train loss 4.404780 | val MSE 0.086729
#   Epoch 07 | train loss 3.892913 | val MSE 0.086071
#   Epoch 08 | train loss 3.505625 | val MSE 0.085441
# Trial 009/16 | {'c_hidden': 32, 'emb_dim': 8, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 1.869368 | val MSE 0.132615
#   Epoch 02 | train loss 1.286515 | val MSE 0.108520
#   Epoch 03 | train loss 1.159837 | val MSE 0.102331
#   Epoch 04 | train loss 1.117263 | val MSE 0.096563
#   Epoch 05 | train loss 1.080655 | val MSE 0.095419
#   Epoch 06 | train loss 1.059180 | val MSE 0.091304
#   Epoch 07 | train loss 1.057609 | val MSE 0.090442
#   Epoch 08 | train loss 1.041926 | val MSE 0.088808
# Trial 010/16 | {'c_hidden': 32, 'emb_dim': 8, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 9.155041 | val MSE 0.122914
#   Epoch 02 | train loss 5.105983 | val MSE 0.105155
#   Epoch 03 | train loss 3.724725 | val MSE 0.096950
#   Epoch 04 | train loss 3.033355 | val MSE 0.094716
#   Epoch 05 | train loss 2.609558 | val MSE 0.092309
#   Epoch 06 | train loss 2.318177 | val MSE 0.089735
#   Epoch 07 | train loss 2.103587 | val MSE 0.088832
#   Epoch 08 | train loss 1.945247 | val MSE 0.087703
# Trial 011/16 | {'c_hidden': 32, 'emb_dim': 8, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 1.926404 | val MSE 0.130996
#   Epoch 02 | train loss 1.310173 | val MSE 0.109203
#   Epoch 03 | train loss 1.168605 | val MSE 0.106039
#   Epoch 04 | train loss 1.121497 | val MSE 0.099167
#   Epoch 05 | train loss 1.081639 | val MSE 0.099671
#   Epoch 06 | train loss 1.058292 | val MSE 0.091949
#   Epoch 07 | train loss 1.059245 | val MSE 0.091018
#   Epoch 08 | train loss 1.041798 | val MSE 0.089965
# Trial 012/16 | {'c_hidden': 32, 'emb_dim': 8, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 9.068228 | val MSE 0.126751
#   Epoch 02 | train loss 5.065884 | val MSE 0.108626
#   Epoch 03 | train loss 3.699161 | val MSE 0.102283
#   Epoch 04 | train loss 3.006037 | val MSE 0.099496
#   Epoch 05 | train loss 2.565983 | val MSE 0.096916
#   Epoch 06 | train loss 2.263370 | val MSE 0.092236
#   Epoch 07 | train loss 2.047637 | val MSE 0.091185
#   Epoch 08 | train loss 1.884806 | val MSE 0.089846
# Trial 013/16 | {'c_hidden': 32, 'emb_dim': 16, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 1.551947 | val MSE 0.116324
#   Epoch 02 | train loss 1.178657 | val MSE 0.101998
#   Epoch 03 | train loss 1.096609 | val MSE 0.096577
#   Epoch 04 | train loss 1.069970 | val MSE 0.091833
#   Epoch 05 | train loss 1.050831 | val MSE 0.089860
#   Epoch 06 | train loss 1.046002 | val MSE 0.089301
#   Epoch 07 | train loss 1.027662 | val MSE 0.089300
#   Epoch 08 | train loss 1.017948 | val MSE 0.088232
# Trial 014/16 | {'c_hidden': 32, 'emb_dim': 16, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 14.918499 | val MSE 0.112187
#   Epoch 02 | train loss 7.369566 | val MSE 0.096558
#   Epoch 03 | train loss 5.214297 | val MSE 0.091785
#   Epoch 04 | train loss 4.174188 | val MSE 0.087992
#   Epoch 05 | train loss 3.511460 | val MSE 0.086508
#   Epoch 06 | train loss 3.052462 | val MSE 0.085413
#   Epoch 07 | train loss 2.724644 | val MSE 0.084716
#   Epoch 08 | train loss 2.484043 | val MSE 0.084192
# Trial 015/16 | {'c_hidden': 32, 'emb_dim': 16, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 1.468809 | val MSE 0.112359
#   Epoch 02 | train loss 1.151188 | val MSE 0.098347
#   Epoch 03 | train loss 1.086650 | val MSE 0.093688
#   Epoch 04 | train loss 1.058254 | val MSE 0.089783
#   Epoch 05 | train loss 1.040763 | val MSE 0.088449
#   Epoch 06 | train loss 1.036133 | val MSE 0.087361
#   Epoch 07 | train loss 1.021649 | val MSE 0.088290
#   Epoch 08 | train loss 1.014655 | val MSE 0.087987
#   Early stopping
# Trial 016/16 | {'c_hidden': 32, 'emb_dim': 16, 'num_heads': 4, 'lr': 0.001, 'lambda_rotate': 0.1, 'corr_threshold': 0.5}
#   Epoch 01 | train loss 14.150804 | val MSE 0.112893
#   Epoch 02 | train loss 7.125243 | val MSE 0.096890
#   Epoch 03 | train loss 5.007397 | val MSE 0.092001
#   Epoch 04 | train loss 3.967228 | val MSE 0.088639
#   Epoch 05 | train loss 3.320417 | val MSE 0.087090
#   Epoch 06 | train loss 2.881176 | val MSE 0.086015
#   Epoch 07 | train loss 2.562816 | val MSE 0.085412
#   Epoch 08 | train loss 2.328005 | val MSE 0.084894
#     c_hidden  emb_dim  num_heads     lr  lambda_rotate  corr_threshold  \
# 0         32       16          2  0.001            0.1             0.5
# 1         32       16          4  0.001            0.1             0.5
# 2         16       16          4  0.001            0.1             0.5
# 3         16       16          2  0.001            0.1             0.5
# 4         16       16          2  0.001            0.0             0.5
# 5         32       16          4  0.001            0.0             0.5
# 6         16       16          4  0.001            0.0             0.5
# 7         32        8          2  0.001            0.1             0.5
# 8         32       16          2  0.001            0.0             0.5
# 9         16        8          2  0.001            0.1             0.5
# 10        32        8          2  0.001            0.0             0.5
# 11        32        8          4  0.001            0.1             0.5
# 12        32        8          4  0.001            0.0             0.5
# 13        16        8          2  0.001            0.0             0.5
# 14        16        8          4  0.001            0.1             0.5
# 15        16        8          4  0.001            0.0             0.5
#
#      model_type  best_epoch  best_val_mse
# 0    GAT_RotatE           8      0.084192
# 1    GAT_RotatE           8      0.084894
# 2    GAT_RotatE           8      0.085441
# 3    GAT_RotatE           8      0.085914
# 4   GAT_lambda0           8      0.086946
# 5   GAT_lambda0           6      0.087361
# 6   GAT_lambda0           7      0.087570
# 7    GAT_RotatE           8      0.087703
# 8   GAT_lambda0           8      0.088232
# 9    GAT_RotatE           8      0.088351
# 10  GAT_lambda0           8      0.088808
# 11   GAT_RotatE           8      0.089846
# 12  GAT_lambda0           8      0.089965
# 13  GAT_lambda0           8      0.091701
# 14   GAT_RotatE           8      0.091853
# 15  GAT_lambda0           8      0.099539
#     model_type   val_mse  test_mse  c_hidden  emb_dim  num_heads     lr  \
# 0   GAT_RotatE  0.084192  1.581573        32       16          2  0.001
# 1  GAT_lambda0  0.086946  1.603411        16       16          2  0.001
#
#    lambda_rotate  corr_threshold
# 0            0.1             0.5
# 1            0.0             0.5

# %%
MSE_dict = {
    key: value['mse_by_firm']
    for key, value in final_results.items()
}

# %%
# Compute the same test metrics as in GAT_Tune Aryaa.ipynb
# for the best lambda=0 model and the best GAT+RotatE model.

metrics_by_group = {}

for group, best in best_by_group.items():
    if 'params' not in best or best.get('state_dict') is None:
        print(f"Skipping {group}: no saved best model found.")
        continue

    params = best['params']
    A_loop = best['A_loop']

    # reload best model
    best_model = build_model(params, A_loop.shape[-1])
    best_model.load_state_dict(best['state_dict'])

    # get predictions
    pred_test = predict_GAT_RotatE(best_model, test_loader, A_loop)
    pred_test_np = pred_test.detach().cpu().numpy()

    # compute metrics
    metrics = compute_metrics(y_test, pred_test_np)
    metrics_by_group[group] = metrics

    print(f"\nModel: {group}")
    print("Best params:", params)
    print("Test metrics:")
    for k, v in metrics.items():
        print(f"  {k}: {v:.4f}")
# Out:
# Model: GAT_lambda0
# Best params: {'c_hidden': 16, 'emb_dim': 16, 'num_heads': 2, 'lr': 0.001, 'lambda_rotate': 0.0, 'corr_threshold': 0.5}
# Test metrics:
#   accuracy: 0.4980
#   f1: 0.4901
#   mcc: -0.0023
#   return_ratio: -2.7383
#   sharpe: -0.2826
#   MSE: 1.6034
